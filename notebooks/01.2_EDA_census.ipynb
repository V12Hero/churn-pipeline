# %%
import numpy as np
import pandas as pd

# %%
housing_material_df = pd.read_csv('../data/01_raw/census/BuildingMaterialofResidentialHousingbyRegionGovernorateandTypeofHousingCSV.csv')
dependency_ratio_df = pd.read_csv('../data/01_raw/census/DependencyRatioandDependentsbyRegionGovernorateandNationalityCSV.csv')
dwellings_df = pd.read_csv('../data/01_raw/census/DwellingsbyRegionGovernorateandCityCSV.csv')
household_ownership_df = pd.read_csv('../data/01_raw/census/HouseOwnershipbyRegionGovernorateandTypeofHousingCSV.csv')
household_df = pd.read_csv('../data/01_raw/census/HouseholdsbyRegionGovernorateNationalityandGenderofHeadofHouseholdCSV.csv')
household_size_df = pd.read_csv('../data/01_raw/census/HouseholdSizebyRegionGovernorateandNationalityofHeadofHouseholdCSV.csv')
household_members_df = pd.read_csv('../data/01_raw/census/NumberofHouseholdMembersbyRegionGovernorateNationalityandGenderofHeadofHouseholdCSV.csv')
household_rooms_df = pd.read_csv('../data/01_raw/census/NumberofRoomsbyRoomTypeRegionGovernorateandTypeofHousingCSV.csv')
household_type_df = pd.read_csv('../data/01_raw/census/PreferredHousingTypeofHouseholdsbyRegionGovernorateNationalityandGenderofHeadofHouseholdCSV.csv')
household_tenure_df = pd.read_csv('../data/01_raw/census/TenurebyRegionGovernorateandTypeofHousingCSV.csv')

# %%
df_list = [
    housing_material_df,
    dwellings_df,
    dependency_ratio_df,
    household_df,
    household_members_df,
    household_rooms_df,
    household_size_df,
    household_tenure_df,
    household_type_df,
    household_ownership_df
]

# %%
for df in df_list:
    display(df)
# Out:
#      Building Material Governorate                         Housing Type  \
# 0          Block/brick     Al Aqiq  Apartment in a Multi-Story Building
# 1          Block/brick     Al Aqiq     Apartment in a Traditional House
# 2          Block/brick     Al Aqiq                 Apartment in a Villa
# 3          Block/brick     Al Aqiq         Floor in a Traditional House
# 4          Block/brick     Al Aqiq                     Floor in a Villa
# ...                ...         ...                                  ...
# 4772             Stone       Umluj  Apartment in a Multi-Story Building
# 4773             Stone       Umluj     Apartment in a Traditional House
# 4774             Stone       Umluj         Floor in a Traditional House
# 4775             Stone       Umluj                                Other
# 4776             Stone       Umluj                    Traditional House
#
#         Region  Housing Units
# 0     Al Bahah              7
# 1     Al Bahah            135
# ...

# %%
household_ownership_df.pivot_table(index="Governorate", values="Houses", columns=["Building material", "Ownership type", "Type of housing unit"], aggfunc="sum")
# Out:
# Building material                            Block/brick  \
# Ownership type                        Not Owning a house
# Type of housing unit Apartment in a Multi-Story Building
# Governorate
# Abha                                                26.0
# Abu Arish                                           17.0
# Ad Dair                                              4.0
# Ad Dammam                                           90.0
# Ad Darb                                             12.0
# ...                                                  ...
# Wadi Ad Dawasir                                      5.0
# Wadi Al Fara                                         NaN
# Yadamah                                              1.0
# Yanbu                                               30.0
# Zahran Al Janub                                      3.0
#
# Building material                                                           \
# Ownership type
# ...

# %%
household_type_df
# Out:
#       Gender Governorate                         Housing Type Nationality  \
# 0     Female     Al Aqiq  Apartment in a Multi-Story Building       Saudi
# 1     Female     Al Aqiq  Apartment in a Multi-Story Building   Non-Saudi
# 2     Female    Al Bahah  Apartment in a Multi-Story Building       Saudi
# 3     Female    Al Bahah  Apartment in a Multi-Story Building   Non-Saudi
# 4     Female   Al Hajrah  Apartment in a Multi-Story Building       Saudi
# ...      ...         ...                                  ...         ...
# 4686    Male       Tabuk                                Villa   Non-Saudi
# 4687    Male       Tayma                                Villa       Saudi
# 4688    Male       Tayma                                Villa   Non-Saudi
# 4689    Male       Umluj                                Villa       Saudi
# 4690    Male       Umluj                                Villa   Non-Saudi
#
#         Region  Housing Units
# 0     Al Bahah                 319
# ...

# %%
hou
