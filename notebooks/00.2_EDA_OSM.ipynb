# %%
import osmium
import geopandas

# %%
fp = osmium.FileProcessor('rio-grande-do-norte-latest.osm.pbf')\
         .with_locations()\
         .with_filter(osmium.filter.EntityFilter(osmium.osm.WAY))\
         .with_filter(osmium.filter.KeyFilter('highway'))\
         .with_filter(osmium.filter.GeoInterfaceFilter())

features = geopandas.GeoDataFrame.from_features(fp)
# Out:
# ---------------------------------------------------------------------------
# InvalidLocationError                      Traceback (most recent call last)
# Cell In[2], line 7
#       1 fp = osmium.FileProcessor('rio-grande-do-norte-latest.osm.pbf')\
#       2          .with_locations()\
#       3          .with_filter(osmium.filter.EntityFilter(osmium.osm.WAY))\
#       4          .with_filter(osmium.filter.KeyFilter('highway'))\
#       5          .with_filter(osmium.filter.GeoInterfaceFilter())
# ----> 7 features = geopandas.GeoDataFrame.from_features(fp)
#
# File ~/anaconda3/envs/petromin/lib/python3.12/site-packages/geopandas/geodataframe.py:732, in GeoDataFrame.from_features(cls, features, crs, columns)
#     729     features_lst = features
#     731 rows = []
# --> 732 for feature in features_lst:
#     733     # load geometry
#     734     if hasattr(feature, "__geo_interface__"):
#     735         feature = feature.__geo_interface__
#
# File ~/anaconda3/envs/petromin/lib/python3.12/site-packages/osmium/file_processor.py:159, in FileProcessor.__iter__(self)
#     157     if self._filtered_handler:
#     158         it.set_filtered_handler(self._filtered_handler)
# --> 159     yield from it
#     160     return
#     162 # need areas, do two pass handling
#
# InvalidLocationError: invalid location

# %%
fp
