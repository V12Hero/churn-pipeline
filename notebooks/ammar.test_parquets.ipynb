# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# open /home/ammar/petromin/data/01_raw/raw_promos.parquet
raw_promos = pd.read_parquet('/home/ammar/petromin/data/01_raw/raw_promos.parquet')
raw_promos.head()
# Out:
#                              Promo
# 0         1 Ltr Synthetic Oil Free
# 1      169 SAR Synthetic Oil Promo
# 2          180 Synthetic Oil Promo
# 3                195 Synthetic Oil
# 4  20W50 Offer (2013 Models) 3 Let

# %%
raw_promos.to_excel('raw_promos.xlsx', index=False)
